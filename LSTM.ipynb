# %%
import os
import numpy as np
import pandas_datareader as pdr
import pandas as pd

# %%
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
df = pd.read_csv(r"C:\Users\pc\Downloads\MSFT (2).csv")

# %%
df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 9444  2023-09-01  331.309998  331.989990  326.779999  328.660004  328.660004
# 9445  2023-09-05  329.000000  334.850006  328.660004  333.549988  333.549988
# 9446  2023-09-06  333.380005  334.459991  330.179993  332.880005  332.880005
# 9447  2023-09-07  331.290009  333.079987  329.029999  329.910004  329.910004
# 9448  2023-09-08  330.089996  336.160004  329.459991  334.269989  334.269989
#
#         Volume
# 9444  14931200
# 9445  18553900
# 9446  17535800
# 9447  18381000
# 9448  19530100

# %%
df.shape
# Out:
# (9449, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9449 entries, 0 to 9448
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       9449 non-null   object
#  1   Open       9449 non-null   float64
#  2   High       9449 non-null   float64
#  3   Low        9449 non-null   float64
#  4   Close      9449 non-null   float64
#  5   Adj Close  9449 non-null   float64
#  6   Volume     9449 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 516.9+ KB

# %%
df = df[['Date','Close']]

# %%
df.head()
# Out:
#          Date     Close
# 0  1986-03-13  0.097222
# 1  1986-03-14  0.100694
# 2  1986-03-17  0.102431
# 3  1986-03-18  0.099826
# 4  1986-03-19  0.098090

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9444    2023-09-01
# 9445    2023-09-05
# 9446    2023-09-06
# 9447    2023-09-07
# 9448    2023-09-08
# Name: Date, Length: 9449, dtype: object

# %%
import datetime

def str_to_datetime(s):
    split = s.split('-')
    year,month,day = int(split[0]),int(split[1]),int(split[2])
    return datetime.datetime(year=year,month=month,day=day)
    
df_object = str_to_datetime("1986-03-13")

df_object
# Out:
# datetime.datetime(1986, 3, 13, 0, 0)

# %%
df['Date']=df['Date'].apply(str_to_datetime)

# %%
df['Date']
# Out:
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9444   2023-09-01
# 9445   2023-09-05
# 9446   2023-09-06
# 9447   2023-09-07
# 9448   2023-09-08
# Name: Date, Length: 9449, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')

# %%
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-09-01  328.660004
# 2023-09-05  333.549988
# 2023-09-06  332.880005
# 2023-09-07  329.910004
# 2023-09-08  334.269989
#
# [9449 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')

plt.plot(df.index,df['Close'])
plt.show()

# %%
def df_windowed(dataframe,first_date_str,last_date_str,n=3):
    first_date = str_to_datetime(first_date_str)
    last_date = str_to_datetime(last_date_str)
    
    target_date = first_date
    
    dates = []
    X,Y = [],[]
    
    last_time = False
    while True:
        df_subset = dataframe.loc[:target_date].tail(n+1)
        
        if len(df_subset)!= n+1:
            print(f'error: window of size {n} is too large for date {target_date}')
            return 
        
        values = df_subset['Close'].to_numpy()
        x,y = values[:-1],values[-1]
        
        dates.append(target_date)
        X.append(x)
        Y.append(y)
        next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
        next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
        next_date_str = next_datetime_str.split('T')[0]
        year_month_day = next_date_str.split("-")
        year,month,day = year_month_day
        next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
        
        if last_time:
            break
            
        target_date = next_date
        
        
        if target_date == last_date:
            last_time = True
            
            
    ret_df = pd.DataFrame({})
    ret_df["Target Date"] = dates
    
    X = np.array(X)
    for i in range(0,n):
        X[:, i]
        ret_df[f'Target-{n-i}'] = X[:, i]
        
    ret_df['Target'] = Y
    
    return ret_df

# start day second time around 22nd september 2022
windowed_df = df_windowed(df,'2022-09-08',"2023-09-08",n=3)

windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2022-09-08  256.059998  253.250000  258.089996  258.519989
# 1    2022-09-09  253.250000  258.089996  258.519989  264.459991
# 2    2022-09-12  258.089996  258.519989  264.459991  266.649994
# 3    2022-09-13  258.519989  264.459991  266.649994  251.990005
# 4    2022-09-14  264.459991  266.649994  251.990005  252.220001
# ..          ...         ...         ...         ...         ...
# 247  2023-09-01  328.410004  328.790009  327.760010  328.660004
# 248  2023-09-05  328.790009  327.760010  328.660004  333.549988
# 249  2023-09-06  327.760010  328.660004  333.549988  332.880005
# 250  2023-09-07  328.660004  333.549988  332.880005  329.910004
# 251  2023-09-08  333.549988  332.880005  329.910004  334.269989
#
# [252 rows x 5 columns]

# %%
def windowed_df_x_y(windowed_dataframe):
    df_as_np = windowed_dataframe.to_numpy()

    dates = df_as_np[:,0]
    
    middle_matrix = df_as_np[:,1:-1]
    X = middle_matrix.reshape((len(dates),middle_matrix.shape[1],1))
    
    Y = df_as_np[:,-1]
    
    return dates,X.astype(np.float32),Y.astype(np.float32)

dates,X,y = windowed_df_x_y(windowed_df)

dates.shape,X.shape,y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates)*.8)
q_90 = int(len(dates)*.9)
dates_train, X_train,y_train = dates[:q_80],X[:q_80],y[:q_80]

dates_val,X_val,y_val = dates[q_80:q_90],X[q_80:q_90],y[q_80:q_90]
dates_test,x_test,y_test = dates[q_90:],X[q_90:],y[q_90:]

plt.plot(dates_train,y_train)
plt.plot(dates_val,y_val)
plt.plot(dates_test,y_test)

plt.legend(['Train','Validation','Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

# %%
model = Sequential([layers.Input((3,1)),
                    layers.LSTM(64),
                   layers.Dense(32,activation = 'relu'),
                   layers.Dense(32,activation = 'relu'),
                   layers.Dense(1)])
model.compile(loss = 'mse',
             optimizer = Adam(learning_rate = 0.01),
             metrics = ['mean_absolute_error'])

model.fit(X_train,y_train,validation_data = (X_val,y_val),epochs = 100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 7s 199ms/step - loss: 71259.7031 - mean_absolute_error: 264.8024 - val_loss: 112073.0312 - val_mean_absolute_error: 334.6925
# Epoch 2/100
# 7/7 [==============================] - 0s 16ms/step - loss: 66270.4453 - mean_absolute_error: 255.1894 - val_loss: 99703.6797 - val_mean_absolute_error: 315.6734
# Epoch 3/100
# 7/7 [==============================] - 0s 18ms/step - loss: 52876.2070 - mean_absolute_error: 227.1370 - val_loss: 71957.7969 - val_mean_absolute_error: 268.1489
# Epoch 4/100
# 7/7 [==============================] - 0s 20ms/step - loss: 27825.0703 - mean_absolute_error: 161.2381 - val_loss: 27717.0820 - val_mean_absolute_error: 166.3223
# Epoch 5/100
# 7/7 [==============================] - 0s 18ms/step - loss: 3576.6304 - mean_absolute_error: 47.8993 - val_loss: 513.2897 - val_mean_absolute_error: 21.4315
# Epoch 6/100
# 7/7 [==============================] - 0s 16ms/step - loss: 6183.3369 - mean_absolute_error: 71.1910 - val_loss: 495.1196 - val_mean_absolute_error: 21.0033
# Epoch 7/100
# 7/7 [==============================] - 0s 16ms/step - loss: 2086.6396 - mean_absolute_error: 39.6163 - val_loss: 9212.7285 - val_mean_absolute_error: 95.7013
# Epoch 8/100
# 7/7 [==============================] - 0s 16ms/step - loss: 2148.6218 - mean_absolute_error: 33.8158 - val_loss: 11592.4648 - val_mean_absolute_error: 107.4173
# Epoch 9/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1772.4199 - mean_absolute_error: 30.0942 - val_loss: 5880.2886 - val_mean_absolute_error: 76.3302
# Epoch 10/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1190.3756 - mean_absolute_error: 30.2995 - val_loss: 3539.8726 - val_mean_absolute_error: 59.0414
# Epoch 11/100
# 7/7 [==============================] - 0s 18ms/step - loss: 1334.4365 - mean_absolute_error: 32.8629 - val_loss: 4674.8433 - val_mean_absolute_error: 67.9769
# Epoch 12/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1147.3318 - mean_absolute_error: 28.4977 - val_loss: 6799.7729 - val_mean_absolute_error: 82.1328
# Epoch 13/100
# 7/7 [==============================] - 0s 31ms/step - loss: 1207.8058 - mean_absolute_error: 27.0589 - val_loss: 6121.5898 - val_mean_absolute_error: 77.8949
# Epoch 14/100
# 7/7 [==============================] - 0s 18ms/step - loss: 1140.3121 - mean_absolute_error: 28.4522 - val_loss: 5057.0342 - val_mean_absolute_error: 70.7323
# Epoch 15/100
# 7/7 [==============================] - 0s 26ms/step - loss: 1158.3578 - mean_absolute_error: 29.6253 - val_loss: 5246.8477 - val_mean_absolute_error: 72.0615
# Epoch 16/100
# 7/7 [==============================] - 0s 18ms/step - loss: 1139.7974 - mean_absolute_error: 28.3713 - val_loss: 5917.6987 - val_mean_absolute_error: 76.5749
# Epoch 17/100
# 7/7 [==============================] - 0s 24ms/step - loss: 1143.9387 - mean_absolute_error: 28.3016 - val_loss: 5561.3838 - val_mean_absolute_error: 74.2119
# Epoch 18/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1147.4502 - mean_absolute_error: 28.2658 - val_loss: 5646.5894 - val_mean_absolute_error: 74.7838
# Epoch 19/100
# 7/7 [==============================] - 0s 21ms/step - loss: 1127.3993 - mean_absolute_error: 28.0256 - val_loss: 5452.7251 - val_mean_absolute_error: 73.4765
# Epoch 20/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1098.0837 - mean_absolute_error: 27.4965 - val_loss: 5382.9175 - val_mean_absolute_error: 73.0027
# Epoch 21/100
# 7/7 [==============================] - 0s 18ms/step - loss: 1044.5861 - mean_absolute_error: 26.8271 - val_loss: 4727.6875 - val_mean_absolute_error: 68.3784
# Epoch 22/100
# 7/7 [==============================] - 0s 18ms/step - loss: 919.3250 - mean_absolute_error: 25.4408 - val_loss: 4036.4890 - val_mean_absolute_error: 63.1185
# Epoch 23/100
# 7/7 [==============================] - 0s 18ms/step - loss: 812.3632 - mean_absolute_error: 23.6855 - val_loss: 4305.4043 - val_mean_absolute_error: 65.2334
# Epoch 24/100
# 7/7 [==============================] - 0s 16ms/step - loss: 768.8719 - mean_absolute_error: 22.9893 - val_loss: 3049.9744 - val_mean_absolute_error: 54.7706
# Epoch 25/100
# 7/7 [==============================] - 0s 18ms/step - loss: 628.3852 - mean_absolute_error: 20.7957 - val_loss: 2369.6504 - val_mean_absolute_error: 48.1459
# Epoch 26/100
# 7/7 [==============================] - 0s 21ms/step - loss: 611.8127 - mean_absolute_error: 20.2542 - val_loss: 2235.1519 - val_mean_absolute_error: 46.7485
# Epoch 27/100
# 7/7 [==============================] - 0s 19ms/step - loss: 427.3829 - mean_absolute_error: 16.9221 - val_loss: 2361.3557 - val_mean_absolute_error: 48.1621
# Epoch 28/100
# 7/7 [==============================] - 0s 16ms/step - loss: 385.1987 - mean_absolute_error: 15.9441 - val_loss: 1516.2393 - val_mean_absolute_error: 38.3110
# Epoch 29/100
# 7/7 [==============================] - 0s 16ms/step - loss: 253.1567 - mean_absolute_error: 12.6344 - val_loss: 1335.9993 - val_mean_absolute_error: 35.9187
# Epoch 30/100
# 7/7 [==============================] - 0s 16ms/step - loss: 201.2315 - mean_absolute_error: 11.1197 - val_loss: 923.9246 - val_mean_absolute_error: 29.5605
# Epoch 31/100
# 7/7 [==============================] - 0s 21ms/step - loss: 291.5681 - mean_absolute_error: 14.2643 - val_loss: 1336.2114 - val_mean_absolute_error: 36.0620
# Epoch 32/100
# 7/7 [==============================] - 0s 16ms/step - loss: 330.4119 - mean_absolute_error: 14.9890 - val_loss: 1262.0813 - val_mean_absolute_error: 35.0422
# Epoch 33/100
# 7/7 [==============================] - 0s 16ms/step - loss: 198.2665 - mean_absolute_error: 11.2610 - val_loss: 521.3461 - val_mean_absolute_error: 21.8402
# Epoch 34/100
# 7/7 [==============================] - 0s 18ms/step - loss: 146.0423 - mean_absolute_error: 9.6853 - val_loss: 353.8282 - val_mean_absolute_error: 17.4694
# Epoch 35/100
# 7/7 [==============================] - 0s 21ms/step - loss: 122.1107 - mean_absolute_error: 8.9094 - val_loss: 315.7672 - val_mean_absolute_error: 16.3767
# Epoch 36/100
# 7/7 [==============================] - 0s 17ms/step - loss: 104.5950 - mean_absolute_error: 8.3511 - val_loss: 431.0881 - val_mean_absolute_error: 19.7032
# Epoch 37/100
# 7/7 [==============================] - 0s 16ms/step - loss: 121.9613 - mean_absolute_error: 8.8585 - val_loss: 468.5095 - val_mean_absolute_error: 20.7274
# Epoch 38/100
# 7/7 [==============================] - 0s 16ms/step - loss: 98.7402 - mean_absolute_error: 8.1137 - val_loss: 319.9728 - val_mean_absolute_error: 16.6795
# Epoch 39/100
# 7/7 [==============================] - 0s 16ms/step - loss: 69.8694 - mean_absolute_error: 6.5332 - val_loss: 220.6620 - val_mean_absolute_error: 13.2721
# Epoch 40/100
# 7/7 [==============================] - 0s 13ms/step - loss: 55.7698 - mean_absolute_error: 5.9022 - val_loss: 249.2797 - val_mean_absolute_error: 14.3841
# Epoch 41/100
# 7/7 [==============================] - 0s 16ms/step - loss: 56.6721 - mean_absolute_error: 5.8513 - val_loss: 190.0945 - val_mean_absolute_error: 12.0710
# Epoch 42/100
# 7/7 [==============================] - 0s 16ms/step - loss: 57.6959 - mean_absolute_error: 5.9596 - val_loss: 195.3892 - val_mean_absolute_error: 12.2913
# Epoch 43/100
# 7/7 [==============================] - 0s 16ms/step - loss: 55.1525 - mean_absolute_error: 5.7830 - val_loss: 184.3045 - val_mean_absolute_error: 11.8819
# Epoch 44/100
# 7/7 [==============================] - 0s 18ms/step - loss: 67.2212 - mean_absolute_error: 6.4786 - val_loss: 198.8560 - val_mean_absolute_error: 12.5913
# Epoch 45/100
# 7/7 [==============================] - 0s 18ms/step - loss: 57.0158 - mean_absolute_error: 6.0483 - val_loss: 170.4645 - val_mean_absolute_error: 11.4459
# Epoch 46/100
# 7/7 [==============================] - 0s 16ms/step - loss: 46.9954 - mean_absolute_error: 5.4739 - val_loss: 106.1922 - val_mean_absolute_error: 8.3765
# Epoch 47/100
# 7/7 [==============================] - 0s 18ms/step - loss: 71.5421 - mean_absolute_error: 6.8053 - val_loss: 111.9296 - val_mean_absolute_error: 8.6561
# Epoch 48/100
# 7/7 [==============================] - 0s 16ms/step - loss: 54.8520 - mean_absolute_error: 5.8294 - val_loss: 179.3226 - val_mean_absolute_error: 11.7967
# Epoch 49/100
# 7/7 [==============================] - 0s 16ms/step - loss: 49.2236 - mean_absolute_error: 5.5670 - val_loss: 242.8906 - val_mean_absolute_error: 14.3522
# Epoch 50/100
# 7/7 [==============================] - 0s 24ms/step - loss: 53.5422 - mean_absolute_error: 5.6465 - val_loss: 141.2977 - val_mean_absolute_error: 10.1346
# Epoch 51/100
# 7/7 [==============================] - 0s 16ms/step - loss: 45.9051 - mean_absolute_error: 5.3529 - val_loss: 184.2991 - val_mean_absolute_error: 12.1183
# Epoch 52/100
# 7/7 [==============================] - 0s 16ms/step - loss: 48.3588 - mean_absolute_error: 5.4875 - val_loss: 82.3659 - val_mean_absolute_error: 7.1154
# Epoch 53/100
# 7/7 [==============================] - 0s 16ms/step - loss: 67.4092 - mean_absolute_error: 6.5730 - val_loss: 150.6742 - val_mean_absolute_error: 10.6972
# Epoch 54/100
# 7/7 [==============================] - 0s 19ms/step - loss: 49.6898 - mean_absolute_error: 5.5181 - val_loss: 201.6747 - val_mean_absolute_error: 12.8624
# Epoch 55/100
# 7/7 [==============================] - 0s 21ms/step - loss: 60.2986 - mean_absolute_error: 6.2973 - val_loss: 248.4011 - val_mean_absolute_error: 14.6348
# Epoch 56/100
# 7/7 [==============================] - 0s 20ms/step - loss: 85.2739 - mean_absolute_error: 7.3357 - val_loss: 109.5240 - val_mean_absolute_error: 8.6774
# Epoch 57/100
# 7/7 [==============================] - 0s 19ms/step - loss: 68.5887 - mean_absolute_error: 6.6015 - val_loss: 91.7281 - val_mean_absolute_error: 7.6675
# Epoch 58/100
# 7/7 [==============================] - 0s 18ms/step - loss: 50.2822 - mean_absolute_error: 5.7803 - val_loss: 120.5223 - val_mean_absolute_error: 9.2438
# Epoch 59/100
# 7/7 [==============================] - 0s 19ms/step - loss: 45.2882 - mean_absolute_error: 5.4056 - val_loss: 144.6457 - val_mean_absolute_error: 10.4557
# Epoch 60/100
# 7/7 [==============================] - 0s 16ms/step - loss: 56.3360 - mean_absolute_error: 5.9142 - val_loss: 75.9981 - val_mean_absolute_error: 6.7529
# Epoch 61/100
# 7/7 [==============================] - 0s 17ms/step - loss: 53.4774 - mean_absolute_error: 5.8566 - val_loss: 113.9280 - val_mean_absolute_error: 9.0175
# Epoch 62/100
# 7/7 [==============================] - 0s 15ms/step - loss: 44.3049 - mean_absolute_error: 5.2389 - val_loss: 110.8495 - val_mean_absolute_error: 8.8735
# Epoch 63/100
# 7/7 [==============================] - 0s 17ms/step - loss: 54.1421 - mean_absolute_error: 5.8149 - val_loss: 76.7852 - val_mean_absolute_error: 6.8969
# Epoch 64/100
# 7/7 [==============================] - 0s 17ms/step - loss: 44.1452 - mean_absolute_error: 5.3144 - val_loss: 92.0015 - val_mean_absolute_error: 7.8589
# Epoch 65/100
# 7/7 [==============================] - 0s 17ms/step - loss: 58.5486 - mean_absolute_error: 6.1659 - val_loss: 181.2673 - val_mean_absolute_error: 12.1253
# Epoch 66/100
# 7/7 [==============================] - 0s 16ms/step - loss: 107.6722 - mean_absolute_error: 8.5196 - val_loss: 88.8446 - val_mean_absolute_error: 7.7143
# Epoch 67/100
# 7/7 [==============================] - 0s 17ms/step - loss: 112.2957 - mean_absolute_error: 8.4665 - val_loss: 47.4088 - val_mean_absolute_error: 5.1419
# Epoch 68/100
# 7/7 [==============================] - 0s 16ms/step - loss: 103.7120 - mean_absolute_error: 8.3342 - val_loss: 95.4439 - val_mean_absolute_error: 8.0725
# Epoch 69/100
# 7/7 [==============================] - 0s 26ms/step - loss: 49.9027 - mean_absolute_error: 5.5779 - val_loss: 57.7836 - val_mean_absolute_error: 5.6257
# Epoch 70/100
# 7/7 [==============================] - 0s 19ms/step - loss: 54.3775 - mean_absolute_error: 5.8351 - val_loss: 80.2118 - val_mean_absolute_error: 7.0013
# Epoch 71/100
# 7/7 [==============================] - 0s 17ms/step - loss: 61.7793 - mean_absolute_error: 6.3375 - val_loss: 174.1159 - val_mean_absolute_error: 11.6573
# Epoch 72/100
# 7/7 [==============================] - 0s 17ms/step - loss: 49.7496 - mean_absolute_error: 5.4652 - val_loss: 56.6999 - val_mean_absolute_error: 5.4218
# Epoch 73/100
# 7/7 [==============================] - 0s 18ms/step - loss: 104.0751 - mean_absolute_error: 8.4154 - val_loss: 130.0816 - val_mean_absolute_error: 9.8934
# Epoch 74/100
# 7/7 [==============================] - 0s 16ms/step - loss: 70.0278 - mean_absolute_error: 6.5964 - val_loss: 91.9895 - val_mean_absolute_error: 8.0051
# Epoch 75/100
# 7/7 [==============================] - 0s 15ms/step - loss: 66.0429 - mean_absolute_error: 6.4428 - val_loss: 46.2488 - val_mean_absolute_error: 5.0335
# Epoch 76/100
# 7/7 [==============================] - 0s 19ms/step - loss: 61.5710 - mean_absolute_error: 6.2124 - val_loss: 89.3237 - val_mean_absolute_error: 7.8058
# Epoch 77/100
# 7/7 [==============================] - 0s 22ms/step - loss: 39.2255 - mean_absolute_error: 4.8345 - val_loss: 119.0258 - val_mean_absolute_error: 9.2909
# Epoch 78/100
# 7/7 [==============================] - 0s 16ms/step - loss: 43.8109 - mean_absolute_error: 5.1971 - val_loss: 81.3843 - val_mean_absolute_error: 7.2554
# Epoch 79/100
# 7/7 [==============================] - 0s 19ms/step - loss: 41.3500 - mean_absolute_error: 5.1167 - val_loss: 137.6281 - val_mean_absolute_error: 10.2042
# Epoch 80/100
# 7/7 [==============================] - 0s 19ms/step - loss: 50.6141 - mean_absolute_error: 5.7600 - val_loss: 81.7235 - val_mean_absolute_error: 7.3319
# Epoch 81/100
# 7/7 [==============================] - 0s 15ms/step - loss: 63.0732 - mean_absolute_error: 6.3217 - val_loss: 83.2023 - val_mean_absolute_error: 7.3949
# Epoch 82/100
# 7/7 [==============================] - 0s 15ms/step - loss: 50.1184 - mean_absolute_error: 5.8017 - val_loss: 227.8294 - val_mean_absolute_error: 14.0080
# Epoch 83/100
# 7/7 [==============================] - 0s 14ms/step - loss: 62.9793 - mean_absolute_error: 6.3002 - val_loss: 86.7028 - val_mean_absolute_error: 7.6334
# Epoch 84/100
# 7/7 [==============================] - 0s 24ms/step - loss: 61.0296 - mean_absolute_error: 6.4926 - val_loss: 56.8900 - val_mean_absolute_error: 5.6073
# Epoch 85/100
# 7/7 [==============================] - 0s 23ms/step - loss: 49.7721 - mean_absolute_error: 5.6909 - val_loss: 120.9673 - val_mean_absolute_error: 9.4555
# Epoch 86/100
# 7/7 [==============================] - 0s 19ms/step - loss: 65.1597 - mean_absolute_error: 6.5837 - val_loss: 129.7616 - val_mean_absolute_error: 9.9276
# Epoch 87/100
# 7/7 [==============================] - 0s 18ms/step - loss: 77.4286 - mean_absolute_error: 7.1300 - val_loss: 43.7218 - val_mean_absolute_error: 5.0932
# Epoch 88/100
# 7/7 [==============================] - 0s 16ms/step - loss: 60.9111 - mean_absolute_error: 5.9869 - val_loss: 64.5738 - val_mean_absolute_error: 6.3423
# Epoch 89/100
# 7/7 [==============================] - 0s 15ms/step - loss: 49.2303 - mean_absolute_error: 5.5533 - val_loss: 86.6487 - val_mean_absolute_error: 7.6902
# Epoch 90/100
# 7/7 [==============================] - 0s 17ms/step - loss: 49.5567 - mean_absolute_error: 5.6198 - val_loss: 44.2263 - val_mean_absolute_error: 4.9478
# Epoch 91/100
# 7/7 [==============================] - 0s 20ms/step - loss: 96.7892 - mean_absolute_error: 8.1189 - val_loss: 88.3765 - val_mean_absolute_error: 7.7653
# Epoch 92/100
# 7/7 [==============================] - 0s 17ms/step - loss: 65.9568 - mean_absolute_error: 6.5186 - val_loss: 92.4484 - val_mean_absolute_error: 7.9794
# Epoch 93/100
# 7/7 [==============================] - 0s 21ms/step - loss: 58.4734 - mean_absolute_error: 5.9723 - val_loss: 84.2109 - val_mean_absolute_error: 7.5330
# Epoch 94/100
# 7/7 [==============================] - 0s 23ms/step - loss: 40.6894 - mean_absolute_error: 4.9902 - val_loss: 53.0262 - val_mean_absolute_error: 5.3669
# Epoch 95/100
# 7/7 [==============================] - 0s 18ms/step - loss: 46.9542 - mean_absolute_error: 5.4427 - val_loss: 45.2936 - val_mean_absolute_error: 5.0039
# Epoch 96/100
# 7/7 [==============================] - 0s 14ms/step - loss: 70.0291 - mean_absolute_error: 6.6912 - val_loss: 50.0010 - val_mean_absolute_error: 5.2551
# Epoch 97/100
# 7/7 [==============================] - 0s 16ms/step - loss: 45.1253 - mean_absolute_error: 5.2358 - val_loss: 96.1416 - val_mean_absolute_error: 8.2569
# Epoch 98/100
# 7/7 [==============================] - 0s 15ms/step - loss: 45.8873 - mean_absolute_error: 5.2795 - val_loss: 100.4828 - val_mean_absolute_error: 8.4908
# Epoch 99/100
# 7/7 [==============================] - 0s 16ms/step - loss: 48.4339 - mean_absolute_error: 5.4133 - val_loss: 45.4963 - val_mean_absolute_error: 5.0293
# Epoch 100/100
# 7/7 [==============================] - 0s 17ms/step - loss: 47.4540 - mean_absolute_error: 5.4163 - val_loss: 113.0071 - val_mean_absolute_error: 9.1188

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train,train_predictions)
plt.plot(dates_train,y_train)
plt.legend(['Training Predictions','Training Observations'])
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val,val_predictions)
plt.plot(dates_val,y_val)
plt.legend(["Validation predictions","Validation Observations"])
# Out:
# 1/1 [==============================] - 0s 25ms/step

# %%
test_predictions = model.predict(x_test).flatten()

plt.plot(dates_test,test_predictions)
plt.plot(dates_test,y_test)
plt.legend(["testing predictions", "testing observations"])
# Out:
# 1/1 [==============================] - 0s 23ms/step

# %%
plt.plot(dates_train,train_predictions)
plt.plot(dates_train,y_train)
plt.plot(dates_val,val_predictions)
plt.plot(dates_val,y_val)
plt.plot(dates_test,test_predictions)
plt.plot(dates_test,y_test)
plt.legend(["training predictions",
          "training observations",
          "validation predictions",
          "validation observations",
          "testing predictions",
          "testing observations"])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val,dates_test])

for target_dates in recursive_dates:
    last_window = deepcopy(X_train[-1])
    next_prediction = model.predict(np.array([last_window])).flatten()
    recursive_predictions.append(next_prediction)
    last_window[-1]= next_prediction
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step

# %%
plt.plot(dates_train,train_predictions)
plt.plot(dates_train,y_train)
plt.plot(dates_val,val_predictions)
plt.plot(dates_val,y_val)
plt.plot(dates_test,test_predictions)
plt.plot(dates_test,y_test)
plt.plot(recursive_dates,recursive_predictions)
plt.legend(["training predictions",
          "training observations",
          "validation predictions",
          "validation observations",
          "testing predictions",
          "testing observations",
           "recursive predictions"])
